# %%
import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

connection = create_connection("review.sqlite")
# Out:
# Connection to SQLite DB successful

# %%
create_articles_table = """
CREATE TABLE IF NOT EXISTS articles (
  pmid INTEGER,
  title TEXT,
  authors TEXT,
  first_author TEXT,
  journal TEXT,
  publication_year YEAR,
  create_date DATE,
  nihms_id TEXT,
  pmcid TEXT,
  doi TEXT,
  of_interest BOOL
);
"""
execute_query(connection, create_articles_table)

create_abstracts_table = """
CREATE TABLE IF NOT EXISTS abstracts (
  abstract TEXT,
  pmid INTEGER,
  FOREIGN KEY (pmid) REFERENCES articles (pmid)
);
"""
execute_query(connection, create_abstracts_table)
# Out:
# Query executed successfully
# Query executed successfully

# %%
create_column = """
ALTER TABLE articles
ADD citation TEXT;
"""
execute_query(connection, create_column)

create_column = """
ALTER TABLE articles
ADD pmcid TEXT;
"""
execute_query(connection, create_column)
# Out:
# Query executed successfully
# The error 'duplicate column name: pmcid' occurred

# %%
f = open("abstracts.txt")
abstracts = f.read().split('\n\n\n')

# %%
import pandas as pd

df = pd.read_csv('articles.csv')
df.columns
# Out:
# Index(['PMID', 'Title', 'Authors', 'Citation', 'First Author', 'Journal/Book',
#        'Publication Year', 'Create Date', 'PMCID', 'NIHMS ID', 'DOI'],
#       dtype='object')

# %%
df.iloc[[34]].values
abstracts[34]
# Out:
# '35. Urology. 2018 Aug;118:30-35. doi: 10.1016/j.urology.2018.03.052. Epub 2018 May \n21.\n\nSimultaneous Bilateral Ureteral Calculi: A New Paradigm for Management.\n\nScotland KB(1), Hubosky SG(2), Tanimoto R(3), Cooper R(4), Healy KA(5), Bagley \nDH(6).\n\nAuthor information:\n(1)Department of Urologic Sciences, University of British Columbia, Vancouver, \nBritish Columbia, Canada.\n(2)Department of Urology, Thomas Jefferson University Hospital, Philadelphia, \nPA.\n(3)Department of Urology, Okayama University Graduate School of Medicine, \nDentistry and Pharmaceutical Sciences, Kita-ku, Okayama, Japan.\n(4)Department of Urology, University of Texas Health Science Center at San \nAntonio, San Antonio, TX.\n(5)Department of Urology, Columbia University Medical Center-New York \nPresbyterian Hospital, New York, NY.\n(6)Department of Urology, Thomas Jefferson University Hospital, Philadelphia, \nPA. Electronic address: Demetrius.bagley@jefferson.edu.\n\nComment in\n    Urology. 2018 A
# ...

# %%
for row in range(len(df)):
    insert_article = f"""
    INSERT INTO
        articles (pmid, title, authors, citation, first_author, journal, publication_year, create_date, pmcid, nihms_id, doi, of_interest)
    VALUES
        ({df.iloc[row]['PMID']}, quote("{df.iloc[row]['Title'].replace('"',"'")}"), "{df.iloc[row]['Authors']}", "{df.iloc[row]['Citation']}", "{df.iloc[row]['First Author']}", "{df.iloc[row]['Journal/Book']}", {df.iloc[row]['Publication Year']}, {df.iloc[row]['Create Date']}, "{df.iloc[row]['PMCID']}", "{df.iloc[row]['NIHMS ID']}", "{df.iloc[row]['DOI']}", NULL);
    """
    execute_query(connection, insert_article)

    insert_abstract = f"""
    INSERT INTO
        abstracts (pmid, abstract)
    VALUES
        ({df.iloc[row]['PMID']}, quote("{abstracts[row].replace('"',"'")}"));
    """
    execute_query(connection, insert_abstract)
# Out:
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# Query executed successfully
# ...

# %% [markdown]
# PMID	Title	Authors	Citation	First Author	Journal/Book	Publication Year	Create Date	PMCID	NIHMS ID	DOI
